# %% [markdown]
# <a href="https://colab.research.google.com/github/Fusik84/County-Workers/blob/main/County_Workers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread ('R1.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)

# %%
image = mpimg.imread ('R2.png')
plt.figure(figsize=(15,6))
plt.axis('off')
plt.imshow(image)
